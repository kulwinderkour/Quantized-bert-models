# %% [markdown]
# ## PTQ

# %%
import sys
print(sys.executable)
# Out:
# d:\IIT JAMMU\Code from scratch\.venv\Scripts\python.exe

# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__)
# Out:
# 3.0.3
